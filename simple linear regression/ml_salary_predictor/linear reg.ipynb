# %%
import pandas as pd 
df = pd.read_csv("C:\ML- Project\life_hr_experience_salary.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\saranraj\AppData\Local\Temp\ipykernel_19144\2817247547.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\ML- Project\life_hr_experience_salary.csv")

# %%
df
# Out:
#      Experience  Salary
# 0          13.9   19.66
# 1           5.7    8.57
# 2           4.5    9.77
# 3          11.0   14.14
# 4          14.4   19.46
# ..          ...     ...
# 995         5.3    9.49
# 996        13.8   20.45
# 997         6.9   10.12
# 998         0.1    2.55
# 999         5.9   10.55
#
# [1000 rows x 2 columns]

# %%
X = df[['Experience']]
Y = df['Salary']

# %%
from sklearn.linear_model import LinearRegression ### importing for model
from sklearn.model_selection import train_test_split ### importing for test train split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print(X_train.shape)  
print(Y_train.shape)
# Out:
# (800, 1)
# (800,)

# %%
## Train the model:
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
###Predict on test data:

Y_pred= model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("MSE:", mean_squared_error(Y_test, Y_pred))
print("R² Score:", r2_score(Y_test, Y_pred))
# Out:
# MSE: 1.9819612948766547
# R² Score: 0.9583980258068739

# %%
print(f"Regression Line: Salary = {model.intercept_:.2f} + {model.coef_[0]:.2f} * Experience")
# Out:
# Regression Line: Salary = 3.09 + 1.19 * Experience

# %%
model.predict([[12]])
# Out:
# C:\Users\saranraj\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17.31835072])

# %%
# Save model to file
import pickle
with open(r'C:\ML- \linear_reg.pkl','wb')  as file:
    pickle.dump(model,file)

# %%
# Load model from file
with open(r'C:\ML- Project\linear_reg.pkl','rb')  as file:
    loaded_model = pickle.load(file)

# %%
loaded_model.predict([[13.9]])
# Out:
# C:\Users\saranraj\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19.5704818])
